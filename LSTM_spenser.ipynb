# %%
import re
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
# load text
spenser = load_doc('data/spenser.txt')
spenser = "\n\n" + spenser
spenser = re.sub("\n\n(.*)\n\n", "\n\n", spenser)[2:]
shakes = load_doc('data/shakespeare.txt')
shakes = ''.join([i for i in shakes if not i.isdigit()])
raw_text = spenser + shakes
# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)

# %%
#organize into sequences of characters
length = 40
n = 1
sequences = list()
for i in range(length, len(raw_text), n):
    # select sequence of tokens
    seq = raw_text[i-length:i+1]
    # store
    sequences.append(seq)

# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()    
# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)

# %%
#load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))

# %%
sequences = list()
for line in lines:
    #integer encode line
    encoded_seq = [mapping[char] for char in line]
    #store
    sequences.append(encoded_seq)
#vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 64

# %%
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
X.shape
# Out:
# (147093, 40, 64)

# %%
# define the model
def define_model(X):
    model = Sequential()
    model.add(LSTM(150, input_shape=(X.shape[1], X.shape[2])))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    return model

# %%
# define model
model = define_model(X)
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
callbacks = [EarlyStopping(monitor='loss', min_delta=0.005, patience=2),
             ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=False, mode='min')]

model.fit(X, y, epochs=100, verbose=2, callbacks=callbacks)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 150)               129000
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                9664
# =================================================================
# Total params: 138,664
# Trainable params: 138,664
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  - 261s - loss: 2.2602 - accuracy: 0.3566
#
# Epoch 00001: saving model to weights-improvement-01-2.2602.hdf5
# Epoch 2/100
#  - 283s - loss: 1.9104 - accuracy: 0.4360
#
# Epoch 00002: saving model to weights-improvement-02-1.9104.hdf5
# Epoch 3/100
#  - 247s - loss: 1.7758 - accuracy: 0.4676
#
# Epoch 00003: saving model to weights-improvement-03-1.7758.hdf5
# Epoch 4/100
#  - 247s - loss: 1.6846 - accuracy: 0.4891
#
# Epoch 00004: saving model to weights-improvement-04-1.6846.hdf5
# Epoch 5/100
#  - 835s - loss: 1.6191 - accuracy: 0.5064
#
# Epoch 00005: saving model to weights-improvement-05-1.6191.hdf5
# Epoch 6/100
#  - 401s - loss: 1.5686 - accuracy: 0.5195
#
# Epoch 00006: saving model to weights-improvement-06-1.5686.hdf5
# Epoch 7/100
#  - 414s - loss: 1.5265 - accuracy: 0.5299
#
# Epoch 00007: saving model to weights-improvement-07-1.5265.hdf5
# Epoch 8/100
#  - 470s - loss: 1.4905 - accuracy: 0.5401
#
# Epoch 00008: saving model to weights-improvement-08-1.4905.hdf5
# Epoch 9/100
#  - 402s - loss: 1.4585 - accuracy: 0.5477
#
# Epoch 00009: saving model to weights-improvement-09-1.4585.hdf5
# Epoch 10/100
#  - 374s - loss: 1.4294 - accuracy: 0.5552
#
# Epoch 00010: saving model to weights-improvement-10-1.4294.hdf5
# Epoch 11/100
#  - 372s - loss: 1.4037 - accuracy: 0.5630
#
# Epoch 00011: saving model to weights-improvement-11-1.4037.hdf5
# Epoch 12/100
#  - 369s - loss: 1.3780 - accuracy: 0.5698
#
# Epoch 00012: saving model to weights-improvement-12-1.3780.hdf5
# Epoch 13/100
#  - 377s - loss: 1.3540 - accuracy: 0.5761
#
# Epoch 00013: saving model to weights-improvement-13-1.3540.hdf5
# Epoch 14/100
#  - 378s - loss: 1.3326 - accuracy: 0.5818
#
# Epoch 00014: saving model to weights-improvement-14-1.3326.hdf5
# Epoch 15/100
#  - 379s - loss: 1.3110 - accuracy: 0.5885
#
# Epoch 00015: saving model to weights-improvement-15-1.3110.hdf5
# Epoch 16/100
#  - 381s - loss: 1.2896 - accuracy: 0.5942
#
# Epoch 00016: saving model to weights-improvement-16-1.2896.hdf5
# Epoch 17/100
#  - 378s - loss: 1.2706 - accuracy: 0.5997
#
# Epoch 00017: saving model to weights-improvement-17-1.2706.hdf5
# Epoch 18/100
#  - 381s - loss: 1.2525 - accuracy: 0.6049
#
# Epoch 00018: saving model to weights-improvement-18-1.2525.hdf5
# Epoch 19/100
#  - 366s - loss: 1.2332 - accuracy: 0.6114
#
# Epoch 00019: saving model to weights-improvement-19-1.2332.hdf5
# Epoch 20/100
#  - 367s - loss: 1.2156 - accuracy: 0.6160
#
# Epoch 00020: saving model to weights-improvement-20-1.2156.hdf5
# Epoch 21/100
#  - 361s - loss: 1.1993 - accuracy: 0.6205
#
# Epoch 00021: saving model to weights-improvement-21-1.1993.hdf5
# Epoch 22/100
#  - 364s - loss: 1.1834 - accuracy: 0.6253
#
# Epoch 00022: saving model to weights-improvement-22-1.1834.hdf5
# Epoch 23/100
#  - 370s - loss: 1.1685 - accuracy: 0.6296
#
# Epoch 00023: saving model to weights-improvement-23-1.1685.hdf5
# Epoch 24/100
#  - 372s - loss: 1.1545 - accuracy: 0.6337
#
# Epoch 00024: saving model to weights-improvement-24-1.1545.hdf5
# Epoch 25/100
#  - 371s - loss: 1.1441 - accuracy: 0.6378
#
# Epoch 00025: saving model to weights-improvement-25-1.1441.hdf5
# Epoch 26/100
#  - 372s - loss: 1.1305 - accuracy: 0.6413
#
# Epoch 00026: saving model to weights-improvement-26-1.1305.hdf5
# Epoch 27/100
#  - 371s - loss: 1.1190 - accuracy: 0.6456
#
# Epoch 00027: saving model to weights-improvement-27-1.1190.hdf5
# Epoch 28/100
#  - 370s - loss: 1.1081 - accuracy: 0.6479
#
# Epoch 00028: saving model to weights-improvement-28-1.1081.hdf5
# Epoch 29/100
#  - 370s - loss: 1.0983 - accuracy: 0.6511
#
# Epoch 00029: saving model to weights-improvement-29-1.0983.hdf5
# Epoch 30/100
#  - 370s - loss: 1.0889 - accuracy: 0.6534
#
# Epoch 00030: saving model to weights-improvement-30-1.0889.hdf5
# Epoch 31/100
#  - 371s - loss: 1.0815 - accuracy: 0.6558
#
# Epoch 00031: saving model to weights-improvement-31-1.0815.hdf5
# Epoch 32/100
#  - 372s - loss: 1.0731 - accuracy: 0.6578
#
# Epoch 00032: saving model to weights-improvement-32-1.0731.hdf5
# Epoch 33/100
#  - 371s - loss: 1.0678 - accuracy: 0.6592
#
# Epoch 00033: saving model to weights-improvement-33-1.0678.hdf5
# Epoch 34/100
#  - 371s - loss: 1.0584 - accuracy: 0.6621
#
# Epoch 00034: saving model to weights-improvement-34-1.0584.hdf5
# Epoch 35/100
#  - 371s - loss: 1.0533 - accuracy: 0.6642
#
# Epoch 00035: saving model to weights-improvement-35-1.0533.hdf5
# Epoch 36/100
#  - 372s - loss: 1.0458 - accuracy: 0.6662
#
# Epoch 00036: saving model to weights-improvement-36-1.0458.hdf5
# Epoch 37/100
#  - 371s - loss: 1.0400 - accuracy: 0.6674
#
# Epoch 00037: saving model to weights-improvement-37-1.0400.hdf5
# Epoch 38/100
#  - 370s - loss: 1.0356 - accuracy: 0.6686
#
# Epoch 00038: saving model to weights-improvement-38-1.0356.hdf5
# Epoch 39/100
#  - 370s - loss: 1.0297 - accuracy: 0.6699
#
# Epoch 00039: saving model to weights-improvement-39-1.0297.hdf5
# Epoch 40/100
#  - 370s - loss: 1.0251 - accuracy: 0.6722
#
# Epoch 00040: saving model to weights-improvement-40-1.0251.hdf5
# Epoch 41/100
#  - 370s - loss: 1.0193 - accuracy: 0.6733
#
# Epoch 00041: saving model to weights-improvement-41-1.0193.hdf5
# Epoch 42/100
#  - 370s - loss: 1.0166 - accuracy: 0.6752
#
# Epoch 00042: saving model to weights-improvement-42-1.0166.hdf5
# Epoch 43/100
#  - 374s - loss: 1.0118 - accuracy: 0.6765
#
# Epoch 00043: saving model to weights-improvement-43-1.0118.hdf5
# Epoch 44/100
#  - 370s - loss: 1.0080 - accuracy: 0.6777
#
# Epoch 00044: saving model to weights-improvement-44-1.0080.hdf5
# Epoch 45/100
#  - 370s - loss: 1.0049 - accuracy: 0.6773
#
# Epoch 00045: saving model to weights-improvement-45-1.0049.hdf5
# Epoch 46/100
#  - 372s - loss: 1.0003 - accuracy: 0.6795
#
# Epoch 00046: saving model to weights-improvement-46-1.0003.hdf5
# Epoch 47/100
#  - 369s - loss: 0.9969 - accuracy: 0.6804
#
# Epoch 00047: saving model to weights-improvement-47-0.9969.hdf5
# Epoch 48/100
#  - 370s - loss: 0.9953 - accuracy: 0.6802
#
# Epoch 00048: saving model to weights-improvement-48-0.9953.hdf5
# Epoch 49/100
#  - 369s - loss: 0.9903 - accuracy: 0.6819
#
# Epoch 00049: saving model to weights-improvement-49-0.9903.hdf5
# Epoch 50/100
#  - 370s - loss: 0.9875 - accuracy: 0.6818
#
# Epoch 00050: saving model to weights-improvement-50-0.9875.hdf5
# Epoch 51/100
#  - 369s - loss: 0.9855 - accuracy: 0.6826
#
# Epoch 00051: saving model to weights-improvement-51-0.9855.hdf5

# %%
# save the model to file
model.save('model_spenser_shakes.h5')
# save the mapping
dump(mapping, open('mapping_spenser_shakes.pkl', 'wb'))
